# %%
#Challenge 1
import pandas as pd

clients=pd.read_csv('./clients.csv')
print(clients)
print('-------------------------------------------------------------------------')
premieres_lignes=clients.head()
dernieres_lignes=clients.tail()

print("Premiere lignes :",premieres_lignes)
print('----------------------------------------------------------------------------')
print("Derniere lignes :",dernieres_lignes)
print('----------------------------------------------------------------------------')
nmbr_ligne_colonne=clients.shape[1]
print("Nombre des colonnes :",nmbr_ligne_colonne)
print('----------------------------------------------------------------------------')
nom_colonne=clients.columns
print(list(nom_colonne))
print('----------------------------------------------------------------------------')
indexes=clients.index
print("Index :",indexes)
print('----------------------------------------------------------------------------')
file_type=clients.dtypes
print("File type :",file_type)
print('----------------------------------------------------------------------------')
clients.info()
print('----------------------------------------------------------------------------')
description=clients.describe()
descriptioncatego=clients.describe(include="object")
print("Description :",description)
print('----------------------------------------------------------------------------')
colonnes_numerique=clients.select_dtypes(include="number").columns
colonnes_catego=clients.select_dtypes(include="object").columns
print("Colonne categor :",colonnes_catego)
print("Colonne numerique :",colonnes_numerique)
print('----------------------------------------------------------------------------')
ville_unique=clients['ville'].unique()
print("Ville unique :",ville_unique)
print('----------------------------------------------------------------------------')
nombre_ville_unique=clients['ville'].nunique()
print("Nombre Ville unique :",nombre_ville_unique)
print('----------------------------------------------------------------------------')
nombre_ville_par_clients=clients['ville'].value_counts()
print("Nombre ville par clients :",nombre_ville_par_clients)
print('----------------------------------------------------------------------------')
valeur_null_colonne=clients.isnull().sum()
valeur_null_total=clients.isnull().sum().sum()
print("Valeur null dans les colonnes :",valeur_null_colonne)
print("Valeur null total",valeur_null_total)
# Out:
#    client_id      nom  age sexe       ville  salaire  anciennete
# 0          1      Ali   25    M  Casablanca     5000           2
# 1          2     Sara   31    F       Rabat     6500           5
# 2          3  Yassine   28    M   Marrakech     4500           3
# 3          4    Salma   35    F  Casablanca     8000           7
# 4          5     Omar   42    M       Rabat     9000          10
# 5          6    Nadia   29    F      Tanger     5200           4
# 6          7    Mehdi   38    M  Casablanca     7500           8
# 7          8    Hajar   26    F   Marrakech     4800           2
# 8          9     Adam   45    M       Rabat    10000          12
# 9         10    Souad   33    F      Tanger     6200           6
# -------------------------------------------------------------------------
# Premiere lignes :    client_id      nom  age sexe       ville  salaire  anciennete
# 0          1      Ali   25    M  Casablanca     5000           2
# 1          2     Sara   31    F       Rabat     6500           5
# 2          3  Yassine   28    M   Marrakech     4500           3
# 3          4    Salma   35    F  Casablanca     8000           7
# 4          5     Omar   42    M       Rabat     9000          10
# ----------------------------------------------------------------------------
# Derniere lignes :    client_id    nom  age sexe       ville  salaire  anciennete
# 5          6  Nadia   29    F      Tanger     5200           4
# 6          7  Mehdi   38    M  Casablanca     7500           8
# 7          8  Hajar   26    F   Marrakech     4800           2
# 8          9   Adam   45    M       Rabat    10000          12
# 9         10  Souad   33    F      Tanger     6200           6
# ----------------------------------------------------------------------------
# Nombre des colonnes : 7
# ----------------------------------------------------------------------------
# ['client_id', 'nom', 'age', 'sexe', 'ville', 'salaire', 'anciennete']
# ----------------------------------------------------------------------------
# Index : RangeIndex(start=0, stop=10, step=1)
# ----------------------------------------------------------------------------
# File type : client_id     int64
# nom             str
# age           int64
# sexe            str
# ville           str
# salaire       int64
# anciennete    int64
# dtype: object
# ----------------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   client_id   10 non-null     int64
#  1   nom         10 non-null     str
#  2   age         10 non-null     int64
#  3   sexe        10 non-null     str
#  4   ville       10 non-null     str
#  5   salaire     10 non-null     int64
#  6   anciennete  10 non-null     int64
# dtypes: int64(4), str(3)
# memory usage: 692.0 bytes
# ----------------------------------------------------------------------------
# Description :        client_id        age       salaire  anciennete
# count   10.00000  10.000000     10.000000   10.000000
# mean     5.50000  33.200000   6670.000000    5.900000
# std      3.02765   6.762642   1896.810188    3.381321
# min      1.00000  25.000000   4500.000000    2.000000
# 25%      3.25000  28.250000   5050.000000    3.250000
# 50%      5.50000  32.000000   6350.000000    5.500000
# 75%      7.75000  37.250000   7875.000000    7.750000
# max     10.00000  45.000000  10000.000000   12.000000
# ----------------------------------------------------------------------------
# Colonne categor : Index(['nom', 'sexe', 'ville'], dtype='str')
# Colonne numerique : Index(['client_id', 'age', 'salaire', 'anciennete'], dtype='str')
# ----------------------------------------------------------------------------
# Ville unique : <StringArray>
# ['Casablanca', 'Rabat', 'Marrakech', 'Tanger']
# Length: 4, dtype: str
# ----------------------------------------------------------------------------
# Nombre Ville unique : 4
# ----------------------------------------------------------------------------
# Nombre ville par clients : ville
# Casablanca    3
# Rabat         3
# Marrakech     2
# Tanger        2
# Name: count, dtype: int64
# ----------------------------------------------------------------------------
# Valeur null dans les colonnes : client_id     0
# nom           0
# age           0
# sexe          0
# ville         0
# salaire       0
# anciennete    0
# dtype: int64
# Valeur null total 0
# C:\Users\USER\AppData\Local\Temp\ipykernel_4008\3675948082.py:29: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   descriptioncatego=clients.describe(include="object")
# C:\Users\USER\AppData\Local\Temp\ipykernel_4008\3675948082.py:33: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   colonnes_catego=clients.select_dtypes(include="object").columns
